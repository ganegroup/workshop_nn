# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](http://colab.research.google.com/github/ganegroup/workshop_nn/blob/main/08b_AlexNet.ipynb)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau
import tensorflow_datasets as tfds
import numpy as np
import seaborn as sns
sns.set_theme()
# Out:
# 2023-07-02 14:54:22.266248: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.config.list_physical_devices()
# Out:
# 2023-07-02 14:54:23.991030: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:23.994423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:23.994636: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.regularizers import l2

# %%
def create_AlexNet(input_shape=[227, 227, 3], num_classes=1000, activation="relu", pooling_layer=layers.MaxPooling2D, batch_normalization=True, kernel_regularizer=l2(5e-4)):
    """Create a keras sequencial model based on the AlexNet architecture"""

    if input_shape == [227, 227, 3]:
        first_kernel_size = 11
        pool_size = 3
    else:
        first_kernel_size = 3
        pool_size = 2

    model = Sequential()
    
    model.add(layers.Conv2D(filters=96, kernel_size=first_kernel_size, strides=4, activation=activation, padding="valid", input_shape=input_shape))
    model.add(pooling_layer(pool_size=pool_size, strides=2, padding="valid"))
    if batch_normalization:
        model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(filters=256, kernel_size=5, strides=1, activation=activation, padding="same", kernel_regularizer=kernel_regularizer))
    model.add(pooling_layer(pool_size=pool_size, strides=2, padding="valid"))
    if batch_normalization:
        model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(filters=384, kernel_size=3, strides=1, activation=activation, padding="same", kernel_regularizer=kernel_regularizer))
    if batch_normalization:
        model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(filters=384, kernel_size=3, strides=1, activation=activation, padding="same", kernel_regularizer=kernel_regularizer))
    if batch_normalization:
        model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(filters=256, kernel_size=3, strides=1, activation=activation, padding="same", kernel_regularizer=kernel_regularizer))
    if batch_normalization:
        model.add(layers.BatchNormalization())

    model.add(pooling_layer(pool_size=pool_size, strides=2, padding="valid"))

    model.add(layers.Flatten())

    model.add(layers.Dense(units=4096, activation=activation))
    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(units=4096, activation=activation))
    model.add(layers.Dropout(0.5))
    
    model.add(layers.Dense(units=num_classes, activation="softmax"))

    return model

# %%
num_classes = 10


AlexNet = create_AlexNet(input_shape=[32, 32, 3], num_classes=num_classes, batch_normalization=False, kernel_regularizer=l2(0.0005))

AlexNet.summary()
# Out:
# 2023-07-02 14:54:24.034337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 96)          2688
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
# 2023-07-02 14:54:24.034522: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:24.034635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:24.405221: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:24.405359: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:24.405453: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-02 14:54:24.405716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21667 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:3f:00.0, compute capability: 8.6
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 21,589,898
# Trainable params: 21,589,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Data loading and preprocessing

(train_data, validation_data), info = tfds.load('cifar10', split=["train", "test"], with_info=True, as_supervised=True)

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='cifar10',
#     full_name='cifar10/3.0.2',
#     description="""
#     The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#     """,
#     homepage='https://www.cs.toronto.edu/~kriz/cifar.html',
#     data_path='/home/user/tensorflow_datasets/cifar10/3.0.2',
#     file_format=tfrecord,
#     download_size=162.17 MiB,
#     dataset_size=132.40 MiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=string),
#         'image': Image(shape=(32, 32, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=50000, num_shards=1>,
#     },
#     citation="""@TECHREPORT{Krizhevsky09learningmultiple,
#         author = {Alex Krizhevsky},
#         title = {Learning multiple layers of features from tiny images},
#         institution = {},
#         year = {2009}
#     }""",
# )

# %%
def normalize(image, label):
    """ Normalize image: `uint8` -> `float32`."""
    return tf.cast(image, tf.float32) / 255., label

def to_categorical(image, label):
    return image, tf.one_hot(tf.cast(label, tf.int32), num_classes)

def pipeline(dataset):
    dataset = dataset.map(normalize)
    dataset = dataset.map(to_categorical)
    dataset = dataset.cache()
    dataset = dataset.shuffle(info.splits['train[:75%]'].num_examples)
    return dataset

processed_train_data = pipeline(train_data)
processed_validation_data = pipeline(validation_data)

batch_size = 32

batched_train_data = processed_train_data.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
batched_validation_data = processed_validation_data.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
lr_reducer = ReduceLROnPlateau(monitor="val_loss", factor=np.sqrt(0.1), patience=5)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)

AlexNet.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %%
normalization_layer = layers.Normalization(axis=None)
normalization_layer.adapt(processed_train_data.map(lambda x, y: x))
# Out:
# 2023-07-02 14:54:24.774859: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype string and shape [1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-07-02 14:54:24.775138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int64 and shape [1]
# 	 [[{{node Placeholder/_4}}]]

# %%
data_augmentation = Sequential([
  layers.RandomFlip("horizontal"),
  layers.RandomZoom((-0.2, 0.2)),
  layers.RandomTranslation(
    (-0.1, 0.1), (-0.1, 0.1)
  ),
  layers.RandomRotation(0.2),
])

# %%
batched_train_data = processed_train_data.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
batched_validation_data = processed_validation_data.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)


batched_train_data = batched_train_data.map(lambda x, y: (normalization_layer(x), y))
batched_train_data = batched_train_data.map(lambda x, y: (data_augmentation(x), y))

batched_validation_data = batched_validation_data.map(lambda x, y: (normalization_layer(x), y))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, _ in batched_train_data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy())
        plt.axis("off")
# Out:
# 2023-07-02 14:54:46.087845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_43' with dtype resource
# 	 [[{{node Placeholder/_43}}]]
# 2023-07-02 14:54:46.088409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [1]
# 	 [[{{node Placeholder/_1}}]]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
history = AlexNet.fit(
    batched_train_data,
    epochs=50,
    validation_data=batched_validation_data,
    callbacks=[lr_reducer]
)
# Out:
# Epoch 1/50
# 2023-07-02 14:54:46.675127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_39' with dtype float and shape [1,1,1]
# 	 [[{{node Placeholder/_39}}]]
# 2023-07-02 14:54:46.675497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_39' with dtype float and shape [1,1,1]
# 	 [[{{node Placeholder/_39}}]]
# 2023-07-02 14:54:47.846166: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-02 14:54:48.357694: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-07-02 14:54:48.359253: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x360e9fd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-02 14:54:48.359270: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A5000, Compute Capability 8.6
# 2023-07-02 14:54:48.404773: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1563/1563 [==============================] - ETA: 0s - loss: 2.4619 - accuracy: 0.2543
# 2023-07-02 14:54:58.463888: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [1]
# 	 [[{{node Placeholder/_0}}]]
# 2023-07-02 14:54:58.464188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype string and shape [1]
# 	 [[{{node Placeholder/_2}}]]
# 1563/1563 [==============================] - 12s 6ms/step - loss: 2.4619 - accuracy: 0.2543 - val_loss: 2.1211 - val_accuracy: 0.3620 - lr: 0.0100
# Epoch 2/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 2.0891 - accuracy: 0.3761 - val_loss: 1.8790 - val_accuracy: 0.4415 - lr: 0.0100
# Epoch 3/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.9188 - accuracy: 0.4154 - val_loss: 1.8222 - val_accuracy: 0.4378 - lr: 0.0100
# Epoch 4/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.8032 - accuracy: 0.4425 - val_loss: 1.7417 - val_accuracy: 0.4736 - lr: 0.0100
# Epoch 5/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.7270 - accuracy: 0.4615 - val_loss: 1.6336 - val_accuracy: 0.4841 - lr: 0.0100
# Epoch 6/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6772 - accuracy: 0.4721 - val_loss: 1.7215 - val_accuracy: 0.4556 - lr: 0.0100
# Epoch 7/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6331 - accuracy: 0.4829 - val_loss: 1.6712 - val_accuracy: 0.4726 - lr: 0.0100
# Epoch 8/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6034 - accuracy: 0.4948 - val_loss: 1.5302 - val_accuracy: 0.5172 - lr: 0.0100
# Epoch 9/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5854 - accuracy: 0.5019 - val_loss: 1.6514 - val_accuracy: 0.4944 - lr: 0.0100
# Epoch 10/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5620 - accuracy: 0.5091 - val_loss: 1.5279 - val_accuracy: 0.5216 - lr: 0.0100
# Epoch 11/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5503 - accuracy: 0.5152 - val_loss: 1.5756 - val_accuracy: 0.5071 - lr: 0.0100
# Epoch 12/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5327 - accuracy: 0.5224 - val_loss: 1.5720 - val_accuracy: 0.5016 - lr: 0.0100
# Epoch 13/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5191 - accuracy: 0.5286 - val_loss: 1.5068 - val_accuracy: 0.5284 - lr: 0.0100
# Epoch 14/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5163 - accuracy: 0.5313 - val_loss: 1.6036 - val_accuracy: 0.4999 - lr: 0.0100
# Epoch 15/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5049 - accuracy: 0.5392 - val_loss: 1.6193 - val_accuracy: 0.5059 - lr: 0.0100
# Epoch 16/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5028 - accuracy: 0.5401 - val_loss: 1.5734 - val_accuracy: 0.5186 - lr: 0.0100
# Epoch 17/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.4993 - accuracy: 0.5413 - val_loss: 1.5200 - val_accuracy: 0.5331 - lr: 0.0100
# Epoch 18/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4967 - accuracy: 0.5463 - val_loss: 1.8656 - val_accuracy: 0.4556 - lr: 0.0100
# Epoch 19/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3696 - accuracy: 0.5902 - val_loss: 1.4058 - val_accuracy: 0.5724 - lr: 0.0032
# Epoch 20/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3258 - accuracy: 0.6012 - val_loss: 1.3572 - val_accuracy: 0.5876 - lr: 0.0032
# Epoch 21/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3026 - accuracy: 0.6081 - val_loss: 1.3953 - val_accuracy: 0.5734 - lr: 0.0032
# Epoch 22/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.2888 - accuracy: 0.6106 - val_loss: 1.3705 - val_accuracy: 0.5823 - lr: 0.0032
# Epoch 23/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2804 - accuracy: 0.6112 - val_loss: 1.3885 - val_accuracy: 0.5703 - lr: 0.0032
# Epoch 24/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2783 - accuracy: 0.6117 - val_loss: 1.3980 - val_accuracy: 0.5707 - lr: 0.0032
# Epoch 25/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2652 - accuracy: 0.6177 - val_loss: 1.3731 - val_accuracy: 0.5759 - lr: 0.0032
# Epoch 26/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1975 - accuracy: 0.6399 - val_loss: 1.3802 - val_accuracy: 0.5756 - lr: 0.0010
# Epoch 27/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1703 - accuracy: 0.6486 - val_loss: 1.2918 - val_accuracy: 0.6039 - lr: 0.0010
# Epoch 28/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1620 - accuracy: 0.6510 - val_loss: 1.3216 - val_accuracy: 0.5979 - lr: 0.0010
# Epoch 29/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1499 - accuracy: 0.6546 - val_loss: 1.3352 - val_accuracy: 0.5908 - lr: 0.0010
# Epoch 30/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1431 - accuracy: 0.6556 - val_loss: 1.3197 - val_accuracy: 0.5989 - lr: 0.0010
# Epoch 31/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1332 - accuracy: 0.6576 - val_loss: 1.2821 - val_accuracy: 0.6055 - lr: 0.0010
# Epoch 32/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1264 - accuracy: 0.6595 - val_loss: 1.3571 - val_accuracy: 0.5812 - lr: 0.0010
# Epoch 33/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1189 - accuracy: 0.6624 - val_loss: 1.2542 - val_accuracy: 0.6181 - lr: 0.0010
# Epoch 34/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1167 - accuracy: 0.6654 - val_loss: 1.2994 - val_accuracy: 0.6035 - lr: 0.0010
# Epoch 35/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1119 - accuracy: 0.6634 - val_loss: 1.2938 - val_accuracy: 0.6040 - lr: 0.0010
# Epoch 36/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1045 - accuracy: 0.6673 - val_loss: 1.2981 - val_accuracy: 0.6016 - lr: 0.0010
# Epoch 37/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0987 - accuracy: 0.6702 - val_loss: 1.3189 - val_accuracy: 0.6007 - lr: 0.0010
# Epoch 38/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1004 - accuracy: 0.6663 - val_loss: 1.2767 - val_accuracy: 0.6104 - lr: 0.0010
# Epoch 39/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0488 - accuracy: 0.6840 - val_loss: 1.2664 - val_accuracy: 0.6120 - lr: 3.1623e-04
# Epoch 40/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0332 - accuracy: 0.6910 - val_loss: 1.2605 - val_accuracy: 0.6142 - lr: 3.1623e-04
# Epoch 41/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0323 - accuracy: 0.6903 - val_loss: 1.2606 - val_accuracy: 0.6132 - lr: 3.1623e-04
# Epoch 42/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0230 - accuracy: 0.6951 - val_loss: 1.2793 - val_accuracy: 0.6117 - lr: 3.1623e-04
# Epoch 43/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0164 - accuracy: 0.6975 - val_loss: 1.2547 - val_accuracy: 0.6207 - lr: 3.1623e-04
# Epoch 44/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0011 - accuracy: 0.7016 - val_loss: 1.2384 - val_accuracy: 0.6231 - lr: 1.0000e-04
# Epoch 45/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9920 - accuracy: 0.7058 - val_loss: 1.2660 - val_accuracy: 0.6173 - lr: 1.0000e-04
# Epoch 46/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9861 - accuracy: 0.7061 - val_loss: 1.2383 - val_accuracy: 0.6268 - lr: 1.0000e-04
# Epoch 47/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9884 - accuracy: 0.7072 - val_loss: 1.2527 - val_accuracy: 0.6223 - lr: 1.0000e-04
# Epoch 48/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9923 - accuracy: 0.7043 - val_loss: 1.2414 - val_accuracy: 0.6253 - lr: 1.0000e-04
# Epoch 49/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9802 - accuracy: 0.7086 - val_loss: 1.2249 - val_accuracy: 0.6295 - lr: 1.0000e-04
# Epoch 50/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9823 - accuracy: 0.7077 - val_loss: 1.2339 - val_accuracy: 0.6261 - lr: 1.0000e-04

# %%
sns.lineplot(x=history.epoch, y=history.history['loss'], label="train loss")
sns.lineplot(x=history.epoch, y=history.history['val_loss'], label="val loss")
# Out:
# <Axes: >

# %%
sns.lineplot(x=history.epoch, y=history.history['accuracy'], label="train accuracy")
sns.lineplot(x=history.epoch, y=history.history['val_accuracy'], label="val accuracy")
# Out:
# <Axes: >
